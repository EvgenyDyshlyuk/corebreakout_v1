# %%
import numpy as np
import matplotlib.pyplot as plt

from skimage import io
import pickle

from PIL import Image
import cv2

from corebreakout import CoreColumn
# Out:
# c:\Users\evgen\Documents\corebreakout\env\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\Users\evgen\Documents\corebreakout\env\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\Users\evgen\Documents\corebreakout\env\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
file_path = 'test_folder/BGS_8858_img_0.jp2'

#file_path = 'tests/data/two_image_dataset/S00101409.jpeg'
image = cv2.imread(file_path)

cv2.imwrite('test_folder/BSG_8858_img_0.jpeg', image)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#Image.fromarray(image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5292/1716393910.py in <module>
#       6 cv2.imwrite('test_folder/BSG_8858_img_0.jpeg', image)
#       7 image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# ----> 8 I#mage.fromarray(image)
#
# NameError: name 'I' is not defined

# %%
file_path = 'test_folder/BGS_8858_img_1.jp2'

#file_path = 'tests/data/two_image_dataset/S00101409.jpeg'
image = cv2.imread(file_path)

cv2.imwrite('test_folder/BGS_8858_img_1.jpeg', image)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#Image.fromarray(image)

# %%
file_path = 'tests/data/two_image_dataset/CoreColumn_1.00_5.00.pkl'
file_path = 'test_folder/CoreColumn_1928.00_1931.00.pkl'
with open(file_path, 'rb') as f:
    col = pickle.load(f)

print(col)
col.plot(figsize=(10, 35), minor_kwargs={'labelsize' : 8})
# Out:
# CoreColumn instance with:
# 	 img.shape: (17965, 778, 3)
# 	 (top, base): (1928.000, 1931.000)
# 	 add_tol & add_mode: 5.0000 , fill
# c:\Users\evgen\Documents\corebreakout\corebreakout\column.py:379: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.yaxis.set_major_formatter(ticker.FixedFormatter((major_ticks)))
# c:\Users\evgen\Documents\corebreakout\corebreakout\column.py:382: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.yaxis.set_minor_formatter(ticker.FixedFormatter((minor_ticks)))
# (<Figure size 720x2520 with 1 Axes>, <AxesSubplot:>)
